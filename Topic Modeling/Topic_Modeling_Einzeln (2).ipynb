# %% [markdown]
# # IMPORTS
#
#
# *   pandas
# *   torch
# *   numpy
# *   bertopic
# *   spacy
# *   string
# *   regex
# *   sidetable
# *   nltk

# %%
import pandas as pd

# %%
pip show pandas
# Out:
# Name: pandas
# Version: 1.3.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: pytz, numpy, python-dateutil
# Required-by: xarray, vega-datasets, statsmodels, sklearn-pandas, seaborn, pymc3, plotnine, pandas-profiling, pandas-gbq, pandas-datareader, mlxtend, mizani, holoviews, gspread-dataframe, google-colab, fix-yahoo-finance, fbprophet, fastai, cufflinks, cmdstanpy, arviz, altair

# %%
import torch

if torch.cuda.is_available():
  device = torch.device("cuda")
else:
  device = torch.device("cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
# !pip install bertopic
from bertopic import BERTopic
#model_for_whole_dataset = BERTopic(language="german", nr_topics="auto")
# Out:
# ...
#      |████████████████████████████████| 58 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 79 kB 7.5 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 45.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 88 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 34.7 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 41.3 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 37.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 37.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 25.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 37.2 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330781 sha256=7d3266133f87c7934d6b211eab8e08b0baea7f91b2489593ca9794b541fed216
# ...

# %%
import numpy as np

# %%
import string
import regex as re
# !pip install sidetable
import sidetable

# %%
# Stopwords
import nltk 
#nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stopwords=set(stopwords.words('german'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stopwords
# Out:
# {'aber',
#  'alle',
#  'allem',
#  'allen',
#  'aller',
#  'alles',
#  'als',
#  'also',
#  'am',
#  'an',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderer',
#  'anderes',
#  'anderm',
#  'andern',
#  'anderr',
#  'anders',
#  'auch',
#  'auf',
#  'aus',
#  'bei',
#  'bin',
#  'bis',
#  'bist',
#  'da',
#  'damit',
#  'dann',
#  'das',
#  'dass',
#  'dasselbe',
#  'dazu',
#  'daß',
#  'dein',
#  'deine',
#  'deinem',
#  'deinen',
#  'deiner',
#  'deines',
#  'dem',
#  'demselben',
#  'den',
#  'denn',
#  'denselben',
#  'der',
#  'derer',
#  'derselbe',
#  'derselben',
#  'des',
#  'desselben',
#  'dessen',
#  'dich',
#  'die',
#  'dies',
#  'diese',
#  'dieselbe',
#  'dieselben',
#  'diesem',
#  'diesen',
#  'dieser',
#  'dieses',
#  'dir',
#  'doch',
#  'dort',
#  'du',
#  'durch',
#  'ein',
#  'eine',
#  'einem',
#  'einen',
#  'einer',
#  'eines',
#  'einig',
#  'einige',
#  'einigem',
#  'einigen',
#  'einiger',
#  'einiges',
#  'einmal',
#  'er',
#  'es',
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Datensätze laden
#
# **Dieser Schritt liefert uns den Datensatz mit den Einträgen aller vier Benchmarks:**
# *   HASOC_AND_GERMEVAL
#
# **Weiterhin liegt jeder Benchmarkdatensatz in einem eigenen DataFrame vor:**
# *   df_hasoc2019
# *   df_hasoc2020
# *   df_germeval2018
# *   df_germeval2019

# %% [markdown]
# ## HASOC

# %% [markdown]
# ### HASOC2019 TRAIN

# %%
hasoc19train = pd.read_csv('german_dataset2019.tsv', sep='\t', encoding='UTF-8')

# %%
hasoc19train.shape
# Out:
# (3819, 4)

# %%
hasoc19train
# Out:
#             text_id                                               text task_1  \
# 0        hasoc_de_1  Frank Rennicke – Ich bin stolz https://t.co/Cm...    NOT
# 1        hasoc_de_2  ANSEHEN.....und danach bitte TEILEN...TEILEN.....    NOT
# 2        hasoc_de_3  #Koeln Mohamed erkennt kein deutsches Recht so...    NOT
# 3        hasoc_de_4  #SaudiArabien ist eine brutale islamische Dikt...    NOT
# 4        hasoc_de_5  Bundespolizei #München hat im 1. Quartal 2019 ...    NOT
# ...             ...                                                ...    ...
# 3814  hasoc_de_3815  akquirieren Männer,die sich um die Kinder kümm...    NOT
# 3815  hasoc_de_3816  Ja,schon seit Jahren!  Ich muß dran denken,das...    NOT
# 3816  hasoc_de_3817  @Kurkamp @wendt_joachim @Schroeder_Live @lamni...    NOT
# 3817  hasoc_de_3818  EU Wahlen!  AfD für Kindererziehungszeiten für...    NOT
# 3818  hasoc_de_3819  Es ist schon merkwürdig,da soll ein Wettstreit...    NOT
#
#      task_2
# 0      NONE
# ...

# %% [markdown]
# ### HASOC2019 TEST

# %%
hasoc19test = pd.read_csv('hasoc_de_test_gold.tsv', sep='\t', encoding='UTF-8')
hasoc19test
# Out:
#            text_id                                               text task_1  \
# 0    hasoc_de_5270  Die Grüne Intelligenz Bestie 'Eckhardt', Prang...    HOF
# 1    hasoc_de_5271  Das Deutschlandlied,  Sinn und Unsinn  https:/...    NOT
# 2    hasoc_de_5272               #Eurovision  https://t.co/24T8fzUI44    NOT
# 3    hasoc_de_5273  Unsere ESC Kandidatinnen haben selbst Schuld a...    HOF
# 4    hasoc_de_5274  Scheinbar bekommt Sarah's Conner's Sohn Vincen...    HOF
# ..             ...                                                ...    ...
# 845  hasoc_de_6115  #Erdogan ruft seine Mops wegen Untauglichkeit ...    HOF
# 846  hasoc_de_6116  Ich würde der Linken Chefin Kipping die 1.000 ...    HOF
# 847  hasoc_de_6117  Ausländer sind Top &amp; Trumpf  Schon aufgefa...    HOF
# 848  hasoc_de_6118  Wie der Regierungsjet die Regierungsflieger wi...    HOF
# 849  hasoc_de_6120  #guteMütter  sind heutzutage gut ausgebildete ...    NOT
#
#     task_2
# 0     HATE
# 1     NONE
# ...

# %% [markdown]
# ### HASOC2019 TRAIN AND TEST

# %%
frames = [hasoc19train, hasoc19test]

# how to ignore auto-generated indeces:
# https://stackoverflow.com/questions/35528119/pandas-recalculate-index-after-a-concatenation
hasoc2019 = pd.concat(frames, ignore_index=True)
display(hasoc2019)
# Out:
#             text_id                                               text task_1  \
# 0        hasoc_de_1  Frank Rennicke – Ich bin stolz https://t.co/Cm...    NOT
# 1        hasoc_de_2  ANSEHEN.....und danach bitte TEILEN...TEILEN.....    NOT
# 2        hasoc_de_3  #Koeln Mohamed erkennt kein deutsches Recht so...    NOT
# 3        hasoc_de_4  #SaudiArabien ist eine brutale islamische Dikt...    NOT
# 4        hasoc_de_5  Bundespolizei #München hat im 1. Quartal 2019 ...    NOT
# ...             ...                                                ...    ...
# 4664  hasoc_de_6115  #Erdogan ruft seine Mops wegen Untauglichkeit ...    HOF
# 4665  hasoc_de_6116  Ich würde der Linken Chefin Kipping die 1.000 ...    HOF
# 4666  hasoc_de_6117  Ausländer sind Top &amp; Trumpf  Schon aufgefa...    HOF
# 4667  hasoc_de_6118  Wie der Regierungsjet die Regierungsflieger wi...    HOF
# 4668  hasoc_de_6120  #guteMütter  sind heutzutage gut ausgebildete ...    NOT
#
#      task_2
# 0      NONE
# ...

# %%
hasoc2019.shape
# Out:
# (4669, 4)

# %%
hasoc2019[4668:4669]
# Out:
#             text_id                                               text task_1  \
# 4668  hasoc_de_6120  #guteMütter  sind heutzutage gut ausgebildete ...    NOT
#
#      task_2
# 4668   NONE

# %% [markdown]
# ### HASOC2020 TRAIN

# %%
hasoc20train = pd.read_excel('hasoc_2020_de_train_new_a.xlsx', converters={'tweet_id':int})
hasoc20train
# Out:
#                  tweet_id                                               text  \
# 0     1133388798925189122  Deutsche rothaarige porno reife deutsche fraue...
# 1     1127134592517980161  RT @NDRinfo: Die deutsche Klimaaktivistin Luis...
# 2     1128897106171842560  @ruhrbahn jeden Morgen eine neue „Fahrzeugstör...
# 3     1123576753199484928  @Junge_Freiheit Die Inkas hatten sich schon dä...
# 4     1128743783393312768  RT @technosteron: leute die 'boar' schreiben l...
# ...                   ...                                                ...
# 2368  1129340066604699649                        in conclusion, ich bin dumm
# 2369  1133032786397409280  RT @chrisjuko: Mit viel Geld an die Macht \n#S...
# 2370  1125397127251804162  @FritzAlter1 @MiriamOzen Ich habe den Eindruck...
# 2371  1128318292228222982  RT @LucaBBM: Wieso hab ich immer Stress mit so...
# 2372  1124962538632957952  RT @tschemal: Deutsche Depressionen https://t....
#
#      task1 task2                  ID
# ...

# %% [markdown]
# ### HASOC2020 TEST

# %%
hasoc20test = pd.read_csv('german_test_1509.csv', sep=',', encoding='UTF-8')
hasoc20test
# Out:
#                 tweet_id                                               text  \
# 0    1129095874242650112    @derCarsti Boykottieren hört sich besser an. 💙💙
# 1    1129004308396236800  RT @ibikus31: Es wird spekuliert, ob Merkel ei...
# 2    1130896929355907080  Hat #Hitler wirklich den Krieg in der Wüste ve...
# 3    1132251534329307136  RT @Beatrix_vStorch: #May tritt in UK unter Tr...
# 4    1124941869115498496  @justmeDoro Eher nicht. Das Gänse hauen wieder...
# ..                   ...                                                ...
# 521  1124809878546128897  RT @ChanMachtSo: SCHMERZEN!!!! Au!!! Mein Gehi...
# 522  1132433240000798720  Die Zerstörung der Grünen. https://t.co/SIYDJj...
# 523  1127366294255357958  RT @PParzival: "Antideutsche" Pseudo-linke Ide...
# 524  1124362090460975105                         Klug reden und dumm leben.
# 525  1131487097293103104  Wissen wir schon lange....hat das die Merkel e...
#
#     task1 task2                  ID
# ...

# %% [markdown]
# ### HASOC2020 TRAIN AND TEST

# %%
frames = [hasoc20train, hasoc20test]
  
hasoc2020 = pd.concat(frames, ignore_index=True)
display(hasoc2020)
# Out:
#                  tweet_id                                               text  \
# 0     1133388798925189122  Deutsche rothaarige porno reife deutsche fraue...
# 1     1127134592517980161  RT @NDRinfo: Die deutsche Klimaaktivistin Luis...
# 2     1128897106171842560  @ruhrbahn jeden Morgen eine neue „Fahrzeugstör...
# 3     1123576753199484928  @Junge_Freiheit Die Inkas hatten sich schon dä...
# 4     1128743783393312768  RT @technosteron: leute die 'boar' schreiben l...
# ...                   ...                                                ...
# 2894  1124809878546128897  RT @ChanMachtSo: SCHMERZEN!!!! Au!!! Mein Gehi...
# 2895  1132433240000798720  Die Zerstörung der Grünen. https://t.co/SIYDJj...
# 2896  1127366294255357958  RT @PParzival: "Antideutsche" Pseudo-linke Ide...
# 2897  1124362090460975105                         Klug reden und dumm leben.
# 2898  1131487097293103104  Wissen wir schon lange....hat das die Merkel e...
#
#      task1 task2                  ID
# ...

# %% [markdown]
# ### HASOC2019 AND HASOC2020

# %%
frames =[hasoc2019, hasoc2020]

hasoc1920 = pd.concat(frames, ignore_index=True)
display(hasoc1920)
# Out:
#          text_id                                               text task_1  \
# 0     hasoc_de_1  Frank Rennicke – Ich bin stolz https://t.co/Cm...    NOT
# 1     hasoc_de_2  ANSEHEN.....und danach bitte TEILEN...TEILEN.....    NOT
# 2     hasoc_de_3  #Koeln Mohamed erkennt kein deutsches Recht so...    NOT
# 3     hasoc_de_4  #SaudiArabien ist eine brutale islamische Dikt...    NOT
# 4     hasoc_de_5  Bundespolizei #München hat im 1. Quartal 2019 ...    NOT
# ...          ...                                                ...    ...
# 7563         NaN  RT @ChanMachtSo: SCHMERZEN!!!! Au!!! Mein Gehi...    NaN
# 7564         NaN  Die Zerstörung der Grünen. https://t.co/SIYDJj...    NaN
# 7565         NaN  RT @PParzival: "Antideutsche" Pseudo-linke Ide...    NaN
# 7566         NaN                         Klug reden und dumm leben.    NaN
# 7567         NaN  Wissen wir schon lange....hat das die Merkel e...    NaN
#
#      task_2      tweet_id task1 task2                  ID
# ...

# %% [markdown]
# ## GERMEVAL

# %% [markdown]
# ### 2018

# %% [markdown]
# #### TRAIN

# %%
germeval2018_train = pd.read_csv('germeval2018training.txt', sep='\t', 
                               encoding='UTF-8', names=('TWEET', 'OFF', 'CAT'))
germeval2018_train
# Out:
#                                                   TWEET      OFF     CAT
# 0     @corinnamilborn Liebe Corinna, wir würden dich...    OTHER   OTHER
# 1     @Martin28a Sie haben ja auch Recht. Unser Twee...    OTHER   OTHER
# 2     @ahrens_theo fröhlicher gruß aus der schönsten...    OTHER   OTHER
# 3     @dushanwegner Amis hätten alles und jeden gewä...    OTHER   OTHER
# 4     @spdde kein verläßlicher Verhandlungspartner. ...  OFFENSE  INSULT
# ...                                                 ...      ...     ...
# 5004  Gegens. Zul. zu Patenamt &amp; gegenseitige An...    OTHER   OTHER
# 5005  @GlasenappHenrik Zu Merkel fällt mir nur ein, ...  OFFENSE  INSULT
# 5006  @KokoLores20 @krippmarie Ein richtiges Zeichen...  OFFENSE   ABUSE
# 5007  @Hartes_Geld ,Honecker‘Merkel macht uns zur ,D...  OFFENSE   ABUSE
# 5008  Warum wurden die G20-Chaoten nicht sofort auf ...    OTHER   OTHER
#
# [5009 rows x 3 columns]

# %% [markdown]
# #### TEST

# %%
# https://stackoverflow.com/questions/35598249/rows-are-lost-when-reading-this-tab-separated-file-with-pandas-read-csv
import csv
germeval2018_test = pd.read_csv('germeval2018test.txt', sep='\t', 
                              encoding='UTF-8', quoting=csv.QUOTE_NONE, names=('TWEET', 'OFF', 'CAT'))
germeval2018_test
# Out:
#                                                   TWEET      OFF    CAT
# 0     Meine Mutter hat mir erzählt, dass mein Vater ...    OTHER  OTHER
# 1     @Tom174_ @davidbest95 Meine Reaktion; |LBR| Ni...    OTHER  OTHER
# 2     #Merkel rollt dem Emir von #Katar, der islamis...    OTHER  OTHER
# 3     „Merle ist kein junges unschuldiges Mädchen“ K...    OTHER  OTHER
# 4     @umweltundaktiv Asylantenflut bringt eben nur ...  OFFENSE  ABUSE
# ...                                                 ...      ...    ...
# 3527  @schlabonski tja, es können einen nicht alle L...    OTHER  OTHER
# 3528  @RKnillmann @lawyerberlin @AfD Aha, der Islam ...  OFFENSE  ABUSE
# 3529  @podilein Mannheim, weltoffen und kunterbunt. ...  OFFENSE  ABUSE
# 3530  @stephanweil was ist nun mit kostenlosen Kitas...    OTHER  OTHER
# 3531  @Bartzissey Denn Minderheiten sind für Linke j...    OTHER  OTHER
#
# [3532 rows x 3 columns]

# %%
frames = [germeval2018_train, germeval2018_test]
germeval2018 = pd.concat(frames, ignore_index= True)

# %%
display(germeval2018)
# Out:
#                                                   TWEET      OFF     CAT
# 0     @corinnamilborn Liebe Corinna, wir würden dich...    OTHER   OTHER
# 1     @Martin28a Sie haben ja auch Recht. Unser Twee...    OTHER   OTHER
# 2     @ahrens_theo fröhlicher gruß aus der schönsten...    OTHER   OTHER
# 3     @dushanwegner Amis hätten alles und jeden gewä...    OTHER   OTHER
# 4     @spdde kein verläßlicher Verhandlungspartner. ...  OFFENSE  INSULT
# ...                                                 ...      ...     ...
# 8536  @schlabonski tja, es können einen nicht alle L...    OTHER   OTHER
# 8537  @RKnillmann @lawyerberlin @AfD Aha, der Islam ...  OFFENSE   ABUSE
# 8538  @podilein Mannheim, weltoffen und kunterbunt. ...  OFFENSE   ABUSE
# 8539  @stephanweil was ist nun mit kostenlosen Kitas...    OTHER   OTHER
# 8540  @Bartzissey Denn Minderheiten sind für Linke j...    OTHER   OTHER
#
# [8541 rows x 3 columns]

# %% [markdown]
# ### 2019

# %% [markdown]
# #### TRAIN 1, 2

# %%
germeval2019_train_subtask_1_2 = pd.read_csv('germeval2019.training_subtask1_2_korrigiert.txt', sep='\t', 
                              encoding='UTF-8', quoting=csv.QUOTE_NONE, names=('TWEET', 'OFF', 'CAT'))
germeval2019_train_subtask_1_2
# Out:
#                                                   TWEET      OFF        CAT
# 0     @jouwatch Hat die Polizei keine Kanone mehr ? ...  OFFENSE      ABUSE
# 1     @de_sputnik @Saudi Arabien habt ihr mal wieder...  OFFENSE      ABUSE
# 2     Glaube ich nicht , die Bundesregierung so wie ...  OFFENSE      ABUSE
# 3     " Doch schockierend viele Jugendliche wissen k...  OFFENSE  PROFANITY
# 4     Sein Charakter war ihm wichtiger anstatt als b...  OFFENSE  PROFANITY
# ...                                                 ...      ...        ...
# 3990  250 Menschen auf der Demonstration gegen das D...    OTHER      OTHER
# 3991  Erneut Massaker an Kurdische ZivilistInnen dur...    OTHER      OTHER
# 3992  Hunderte Refugees haben die Grenze zur spanisc...    OTHER      OTHER
# 3993  Heute ab 17:00 Uhr an der Alten Oper FFM: Kund...    OTHER      OTHER
# 3994  Uns gibt es jetzt auch auf #twitter. Folgt uns...    OTHER      OTHER
#
# [3995 rows x 3 columns]

# %% [markdown]
# #### TRAIN 3
# nicht mehr teil des TM, da es aus den GermEval2018-Daten besteht (Doppelung)

# %%
#germeval2019_train_subtask_3 = pd.read_csv('germeval2019.training_subtask3.txt', sep='\t', 
#                              encoding='UTF-8', names=('TWEET', 'OFF', 'CAT', 'EXPL'))

#germeval2019_train_subtask_3

# %% [markdown]
# #### TRAIN 1, 2 und 3

# %%
#frames = [germeval2019_train_subtask_1_2, germeval2019_train_subtask_3]
#germeval2019_train = pd.concat(frames, ignore_index=True)
#germeval2019_train
#display(germeval2019_train)

# %% [markdown]
# #### TEST 1, 2

# %%
germeval2019_test_sub_1_2 = pd.read_csv('germeval2019_Testdata_Subtask12.txt', sep='\t', 
                                        encoding='UTF-8')
germeval2019_test_sub_1_2
# Out:
#                                                   TWEET
# 0     @JanZimmHHB @mopo Komisch das die Realitätsver...
# 1     @faznet @Gruene_Europa @SPDEuropa @CDU CDU ste...
# 2     @DLFNachrichten Die Gesichter, Namen, Religion...
# 3     @welt Wie verwirrt muss man sein um sich zu we...
# 4     @hacker_1991 @torben_braga Weil die AfD den Fe...
# ...                                                 ...
# 3026  Es fand aber nie eine Emanzipierungs-Phase der...
# 3027  Um es klar zu stellen: Ich will hier kein Whit...
# 3028  Und dann habe ich da noch die McArthur-Briefe ...
# 3029  Mal sehen wer der Ersatzmann wird. Hier könnte...
# 3030  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...
#
# [3031 rows x 1 columns]

# %% [markdown]
# #### TEST 3
# nicht mehr teil des TM, da es aus den GermEval2018-Daten besteht (Doppelung)

# %%
#germeval2019_test_sub_3 = pd.read_csv('germeval2019_Testdata_Subtask3.txt', sep='\t', 
#                                  encoding='UTF-8', names=('TWEET', 'OFF', 'CAT', 'EXPL'))
#germeval2019_test_sub_3.head()

#germeval2019_test_sub_3

# %% [markdown]
# #### TEST 1, 2, 3

# %%
#frames = [germeval2019_test_sub_1_2, germeval2019_test_sub_3]
#germeval2019_test = pd.concat(frames, ignore_index=True)
#germeval2019_test

# %% [markdown]
# #### GOLD 1, 2

# %%
#germeval2019_gold_sub_1_2 = pd.read_csv('germeval2019GoldLabelsSubtask1_2.txt', sep='\t',
#                                       encoding='UTF-8', names=('TWEET', 'OFF', 'CAT', 'EXPL'))
#germeval2019_gold_sub_1_2
#germeval2019_gold_sub_1_2

# %% [markdown]
# #### GOLD 3

# %%
#germeval2019_gold_sub_3 = pd.read_csv('germeval2019GoldLabelsSubtask3.txt', sep='\t', 
#                                      encoding='UTF-8', names=('TWEET', 'OFF', 'CAT', 'EXPL'))
#germeval2019_gold_sub_3
#germeval2019_gold_sub_3

# %% [markdown]
# #### GOLD 1, 2, 3

# %%
#frames = [germeval2019_gold_sub_1_2, germeval2019_gold_sub_3]
#germeval2019_gold = pd.concat(frames, ignore_index=True)
#germeval2019_gold

# %% [markdown]
# #### TRAIN AND TEST

# %%
# Gold und Test sind die gleichen Datensätze, 
# daher wird an dieser Stelle nur einer der zwei
# verwendet

frames = [germeval2019_train_subtask_1_2, germeval2019_test_sub_1_2]


#frames = [germeval2019_train, germeval2019_gold]

germeval2019 = pd.concat(frames, ignore_index=True)
germeval2019
# Out:
#                                                   TWEET      OFF        CAT
# 0     @jouwatch Hat die Polizei keine Kanone mehr ? ...  OFFENSE      ABUSE
# 1     @de_sputnik @Saudi Arabien habt ihr mal wieder...  OFFENSE      ABUSE
# 2     Glaube ich nicht , die Bundesregierung so wie ...  OFFENSE      ABUSE
# 3     " Doch schockierend viele Jugendliche wissen k...  OFFENSE  PROFANITY
# 4     Sein Charakter war ihm wichtiger anstatt als b...  OFFENSE  PROFANITY
# ...                                                 ...      ...        ...
# 7021  Es fand aber nie eine Emanzipierungs-Phase der...      NaN        NaN
# 7022  Um es klar zu stellen: Ich will hier kein Whit...      NaN        NaN
# 7023  Und dann habe ich da noch die McArthur-Briefe ...      NaN        NaN
# 7024  Mal sehen wer der Ersatzmann wird. Hier könnte...      NaN        NaN
# 7025  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...      NaN        NaN
#
# [7026 rows x 3 columns]

# %% [markdown]
# ### 2018 AND 2019

# %%
frames =[germeval2018, germeval2019]

germeval1819 = pd.concat(frames, ignore_index=True)
#display(germeval1819)

# %% [markdown]
# ## HASOC1920 AND GERMEVAL1819

# %%
frames = [hasoc1920['text'], germeval1819['TWEET']]
HASOC_AND_GERMEVAL = pd.concat(frames, ignore_index=True)
HASOC_AND_GERMEVAL = pd.DataFrame(HASOC_AND_GERMEVAL)
HASOC_AND_GERMEVAL
#display(HASOC_AND_GERMEVAL)
#HASOC_AND_GERMEVAL[25915]
# Out:
#                                                        0
# 0      Frank Rennicke – Ich bin stolz https://t.co/Cm...
# 1      ANSEHEN.....und danach bitte TEILEN...TEILEN.....
# 2      #Koeln Mohamed erkennt kein deutsches Recht so...
# 3      #SaudiArabien ist eine brutale islamische Dikt...
# 4      Bundespolizei #München hat im 1. Quartal 2019 ...
# ...                                                  ...
# 23130  Es fand aber nie eine Emanzipierungs-Phase der...
# 23131  Um es klar zu stellen: Ich will hier kein Whit...
# 23132  Und dann habe ich da noch die McArthur-Briefe ...
# 23133  Mal sehen wer der Ersatzmann wird. Hier könnte...
# 23134  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...
#
# [23135 rows x 1 columns]

# %%
HASOC_AND_GERMEVAL_DF = HASOC_AND_GERMEVAL.set_axis(['tweet'], axis = 1, inplace = False)
HASOC_AND_GERMEVAL_DF
# Out:
#                                                    tweet
# 0      Frank Rennicke – Ich bin stolz https://t.co/Cm...
# 1      ANSEHEN.....und danach bitte TEILEN...TEILEN.....
# 2      #Koeln Mohamed erkennt kein deutsches Recht so...
# 3      #SaudiArabien ist eine brutale islamische Dikt...
# 4      Bundespolizei #München hat im 1. Quartal 2019 ...
# ...                                                  ...
# 23130  Es fand aber nie eine Emanzipierungs-Phase der...
# 23131  Um es klar zu stellen: Ich will hier kein Whit...
# 23132  Und dann habe ich da noch die McArthur-Briefe ...
# 23133  Mal sehen wer der Ersatzmann wird. Hier könnte...
# 23134  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...
#
# [23135 rows x 1 columns]

# %% [markdown]
# ## Alle vier Datensätze

# %%
df_hasoc2019 = pd.DataFrame(hasoc2019)
df_hasoc2019
# Out:
#             text_id                                               text task_1  \
# 0        hasoc_de_1  Frank Rennicke – Ich bin stolz https://t.co/Cm...    NOT
# 1        hasoc_de_2  ANSEHEN.....und danach bitte TEILEN...TEILEN.....    NOT
# 2        hasoc_de_3  #Koeln Mohamed erkennt kein deutsches Recht so...    NOT
# 3        hasoc_de_4  #SaudiArabien ist eine brutale islamische Dikt...    NOT
# 4        hasoc_de_5  Bundespolizei #München hat im 1. Quartal 2019 ...    NOT
# ...             ...                                                ...    ...
# 4664  hasoc_de_6115  #Erdogan ruft seine Mops wegen Untauglichkeit ...    HOF
# 4665  hasoc_de_6116  Ich würde der Linken Chefin Kipping die 1.000 ...    HOF
# 4666  hasoc_de_6117  Ausländer sind Top &amp; Trumpf  Schon aufgefa...    HOF
# 4667  hasoc_de_6118  Wie der Regierungsjet die Regierungsflieger wi...    HOF
# 4668  hasoc_de_6120  #guteMütter  sind heutzutage gut ausgebildete ...    NOT
#
#      task_2
# 0      NONE
# ...

# %%
df_hasoc2020 = pd.DataFrame(hasoc2020)
df_hasoc2020
# Out:
#                  tweet_id                                               text  \
# 0     1133388798925189122  Deutsche rothaarige porno reife deutsche fraue...
# 1     1127134592517980161  RT @NDRinfo: Die deutsche Klimaaktivistin Luis...
# 2     1128897106171842560  @ruhrbahn jeden Morgen eine neue „Fahrzeugstör...
# 3     1123576753199484928  @Junge_Freiheit Die Inkas hatten sich schon dä...
# 4     1128743783393312768  RT @technosteron: leute die 'boar' schreiben l...
# ...                   ...                                                ...
# 2894  1124809878546128897  RT @ChanMachtSo: SCHMERZEN!!!! Au!!! Mein Gehi...
# 2895  1132433240000798720  Die Zerstörung der Grünen. https://t.co/SIYDJj...
# 2896  1127366294255357958  RT @PParzival: "Antideutsche" Pseudo-linke Ide...
# 2897  1124362090460975105                         Klug reden und dumm leben.
# 2898  1131487097293103104  Wissen wir schon lange....hat das die Merkel e...
#
#      task1 task2                  ID
# ...

# %%
df_germeval2018 = pd.DataFrame(germeval2018)
df_germeval2018
# Out:
#                                                   TWEET      OFF     CAT
# 0     @corinnamilborn Liebe Corinna, wir würden dich...    OTHER   OTHER
# 1     @Martin28a Sie haben ja auch Recht. Unser Twee...    OTHER   OTHER
# 2     @ahrens_theo fröhlicher gruß aus der schönsten...    OTHER   OTHER
# 3     @dushanwegner Amis hätten alles und jeden gewä...    OTHER   OTHER
# 4     @spdde kein verläßlicher Verhandlungspartner. ...  OFFENSE  INSULT
# ...                                                 ...      ...     ...
# 8536  @schlabonski tja, es können einen nicht alle L...    OTHER   OTHER
# 8537  @RKnillmann @lawyerberlin @AfD Aha, der Islam ...  OFFENSE   ABUSE
# 8538  @podilein Mannheim, weltoffen und kunterbunt. ...  OFFENSE   ABUSE
# 8539  @stephanweil was ist nun mit kostenlosen Kitas...    OTHER   OTHER
# 8540  @Bartzissey Denn Minderheiten sind für Linke j...    OTHER   OTHER
#
# [8541 rows x 3 columns]

# %%
df_germeval2019 = pd.DataFrame(germeval2019)
df_germeval2019
# Out:
#                                                   TWEET      OFF        CAT
# 0     @jouwatch Hat die Polizei keine Kanone mehr ? ...  OFFENSE      ABUSE
# 1     @de_sputnik @Saudi Arabien habt ihr mal wieder...  OFFENSE      ABUSE
# 2     Glaube ich nicht , die Bundesregierung so wie ...  OFFENSE      ABUSE
# 3     " Doch schockierend viele Jugendliche wissen k...  OFFENSE  PROFANITY
# 4     Sein Charakter war ihm wichtiger anstatt als b...  OFFENSE  PROFANITY
# ...                                                 ...      ...        ...
# 7021  Es fand aber nie eine Emanzipierungs-Phase der...      NaN        NaN
# 7022  Um es klar zu stellen: Ich will hier kein Whit...      NaN        NaN
# 7023  Und dann habe ich da noch die McArthur-Briefe ...      NaN        NaN
# 7024  Mal sehen wer der Ersatzmann wird. Hier könnte...      NaN        NaN
# 7025  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...      NaN        NaN
#
# [7026 rows x 3 columns]

# %% [markdown]
# #Funktionen für Preprocessing und Cleaning
#
# Quelle:
# https://towardsai.net/p/programming/tweet-topic-modeling-part-2-cleaning-and-preprocessing-tweets
# https://gist.github.com/bicachu/09cc71bb4b0e3711eaf1556b12fa7ad7

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stopwords=set(stopwords.words('german'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
import pandas as pd
import re
import gensim
from nltk.stem import WordNetLemmatizer


punctuation = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~•@'         # define a string of punctuation symbols

# Functions to clean tweets
def remove_links(tweet):
    """Takes a string and removes web links from it"""
    tweet = re.sub(r'http\S+', '', tweet)   # remove http links
    tweet = re.sub(r'bit.ly/\\S+', '', tweet)  # remove bitly links
    tweet = tweet.strip('[link]')   # remove [links]
    tweet = re.sub(r'pic.twitter\\S+','', tweet)
    return tweet

def remove_users(tweet):
    """Takes a string and removes retweet and @user information"""
    tweet = re.sub('(RT\\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet)  # remove re-tweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet)  # remove tweeted at
    return tweet

def remove_hashtags(tweet):
    """Takes a string and removes any hash tags"""
    tweet = re.sub('(#[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet)  # remove hash tags
    return tweet

def remove_av(tweet):
    """Takes a string and removes AUDIO/VIDEO tags or labels"""
    tweet = re.sub('VIDEO:', '', tweet)  # remove 'VIDEO:' from start of tweet
    tweet = re.sub('AUDIO:', '', tweet)  # remove 'AUDIO:' from start of tweet
    return tweet

def tokenize(tweet):
    """Returns tokenized representation of words in lemma form excluding stopwords"""
    result = []
    for token in gensim.utils.simple_preprocess(tweet):
        if token not in stopwords and len(token) > 2:  # drops words with less than 3 characters
            result.append(lemmatize(token))
    return result

def lemmatize(token):
    """Returns lemmatization of a token"""
    return WordNetLemmatizer().lemmatize(token, pos='v')

def preprocess_tweet(tweet):
    """Main master function to clean tweets, stripping noisy characters, and tokenizing use lemmatization"""
    tweet = remove_links(tweet)
    tweet = remove_users(tweet)
    tweet = remove_hashtags(tweet)
    tweet = remove_av(tweet)
    tweet = tweet.lower()  # lower case
    tweet = re.sub('[' + punctuation + ']+', ' ', tweet)  # strip punctuation
    tweet = re.sub('\\s+', ' ', tweet)  # remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet)  # remove numbers
    tweet_token_list = tokenize(tweet)  # apply lemmatization and tokenization
    tweet = ' '.join(tweet_token_list)
    return tweet

def basic_clean(tweet):
    """Main master function to clean tweets only without tokenization or removal of stopwords"""
    tweet = remove_users(tweet)
    tweet = remove_links(tweet)
    tweet = remove_hashtags(tweet)
    tweet = remove_av(tweet)
    tweet = tweet.lower()  # lower case
    tweet = re.sub('[' + punctuation + ']+', ' ', tweet)  # strip punctuation
    tweet = re.sub('\\s+', ' ', tweet)  # remove double spacing
    tweet = re.sub('([0-9]+)', '', tweet)  # remove numbers
    tweet = re.sub('📝 …', '', tweet)
    return tweet

def tokenize_tweets(df):
    """Main function to read in and return cleaned and preprocessed dataframe.
    This can be used in Jupyter notebooks by importing this module and calling the tokenize_tweets() function
    Args:
        df = data frame object to apply cleaning to
    Returns:
        pandas data frame with cleaned tokens
    """

    df['tokens'] = df.tweet.apply(preprocess_tweet)
    num_tweets = len(df)
    print('Complete. Number of Tweets that have been cleaned and tokenized : {}'.format(num_tweets))
    return df

# %% [markdown]
# # TM GermEval 2018: unprocessed

# %%
tweets_df_germ_2018 = df_germeval2018.copy()
tweets_df_germ_2018
# Out:
#                                                   TWEET      OFF     CAT
# 0     @corinnamilborn Liebe Corinna, wir würden dich...    OTHER   OTHER
# 1     @Martin28a Sie haben ja auch Recht. Unser Twee...    OTHER   OTHER
# 2     @ahrens_theo fröhlicher gruß aus der schönsten...    OTHER   OTHER
# 3     @dushanwegner Amis hätten alles und jeden gewä...    OTHER   OTHER
# 4     @spdde kein verläßlicher Verhandlungspartner. ...  OFFENSE  INSULT
# ...                                                 ...      ...     ...
# 8536  @schlabonski tja, es können einen nicht alle L...    OTHER   OTHER
# 8537  @RKnillmann @lawyerberlin @AfD Aha, der Islam ...  OFFENSE   ABUSE
# 8538  @podilein Mannheim, weltoffen und kunterbunt. ...  OFFENSE   ABUSE
# 8539  @stephanweil was ist nun mit kostenlosen Kitas...    OTHER   OTHER
# 8540  @Bartzissey Denn Minderheiten sind für Linke j...    OTHER   OTHER
#
# [8541 rows x 3 columns]

# %%
docs = tweets_df_germ_2018['TWEET'].copy()

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer


german_stop_words = stopwords.words('german')

# %%
pip install --upgrade tbb

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)

# %%
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")

# %%
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                               Name
# 0      -1   3226                              -1_lbr_ja_schon_heute
# 1       0   3212                        0_lbr_merkel_deutschland_ja
# 2       1    370                      1_islam_moslems_muslime_koran
# 3       2    221               2_flüchtlinge_asyl_fakt_flüchtlingen
# 4       3    220                  3_israel_antisemitismus_juden_amp
# 5       4    166                        4_türken_türkei_erdogan_lbr
# 6       5    137                    5_spd_groko_ralf_stegner_spdler
# 7       6    128          6_kirche_religion_rspctfl_drkassandrapari
# 8       7    108                      7_nazis_nazi_holocaust_hitler
# 9       8    106                            8_grünen_grüne_grün_afd
# 10      9     76                       9_afd_npd_lbr_afdimbundestag
# 11     10     63                      10_trump_donald_lbr_präsident
# 12     11     62         11_rassismus_rassistischen_hautfarbe_rasse
# ...

# %%
#topic_df = topic_model.get_topic_info(top_n_topics=20)
topic_df.head(20)
# Out:
#     Topic  Count                                          Name
# 0      -1   3226                         -1_lbr_ja_schon_heute
# 1       0   3212                   0_lbr_merkel_deutschland_ja
# 2       1    370                 1_islam_moslems_muslime_koran
# 3       2    221          2_flüchtlinge_asyl_fakt_flüchtlingen
# 4       3    220             3_israel_antisemitismus_juden_amp
# 5       4    166                   4_türken_türkei_erdogan_lbr
# 6       5    137               5_spd_groko_ralf_stegner_spdler
# 7       6    128     6_kirche_religion_rspctfl_drkassandrapari
# 8       7    108                 7_nazis_nazi_holocaust_hitler
# 9       8    106                       8_grünen_grüne_grün_afd
# 10      9     76                  9_afd_npd_lbr_afdimbundestag
# 11     10     63                 10_trump_donald_lbr_präsident
# 12     11     62    11_rassismus_rassistischen_hautfarbe_rasse
# 13     12     61  12_journalismus_medien_maischberger_fakenews
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#from bertopic import BERTopic
#topic_model = BERTopic()
#topic_model.save("tm_germeval2018_unprocessed")

# %%
#topic_model = BERTopic.load("tm_germeval2018_unprocessed")

# %% [markdown]
# # TM GermEval 2018: processed

# %%
tweets_df_new_germ_2018 = tweets_df_germ_2018[['TWEET']].copy()

tweets_df_new_germ_2018
# Out:
#                                                   TWEET
# 0     @corinnamilborn Liebe Corinna, wir würden dich...
# 1     @Martin28a Sie haben ja auch Recht. Unser Twee...
# 2     @ahrens_theo fröhlicher gruß aus der schönsten...
# 3     @dushanwegner Amis hätten alles und jeden gewä...
# 4     @spdde kein verläßlicher Verhandlungspartner. ...
# ...                                                 ...
# 8536  @schlabonski tja, es können einen nicht alle L...
# 8537  @RKnillmann @lawyerberlin @AfD Aha, der Islam ...
# 8538  @podilein Mannheim, weltoffen und kunterbunt. ...
# 8539  @stephanweil was ist nun mit kostenlosen Kitas...
# 8540  @Bartzissey Denn Minderheiten sind für Linke j...
#
# [8541 rows x 1 columns]

# %%
tweets_df_new_germ_2018 = tweets_df_new_germ_2018.rename(columns={'TWEET':'tweet'})
type(tweets_df_new_germ_2018)
# Out:
# pandas.core.frame.DataFrame

# %%
tweets_df_new_germ_2018
# Out:
#                                                   tweet
# 0     @corinnamilborn Liebe Corinna, wir würden dich...
# 1     @Martin28a Sie haben ja auch Recht. Unser Twee...
# 2     @ahrens_theo fröhlicher gruß aus der schönsten...
# 3     @dushanwegner Amis hätten alles und jeden gewä...
# 4     @spdde kein verläßlicher Verhandlungspartner. ...
# ...                                                 ...
# 8536  @schlabonski tja, es können einen nicht alle L...
# 8537  @RKnillmann @lawyerberlin @AfD Aha, der Islam ...
# 8538  @podilein Mannheim, weltoffen und kunterbunt. ...
# 8539  @stephanweil was ist nun mit kostenlosen Kitas...
# 8540  @Bartzissey Denn Minderheiten sind für Linke j...
#
# [8541 rows x 1 columns]

# %%
#tweets_df_new = tweets_df_new.drop('TWEET', axis=1)

# %%
tweets_df_new_germ_2018 = tokenize_tweets(tweets_df_new_germ_2018)
tweets_df_new_germ_2018
# Out:
# Complete. Number of Tweets that have been cleaned and tokenized : 8541
#                                                   tweet  \
# 0     @corinnamilborn Liebe Corinna, wir würden dich...
# 1     @Martin28a Sie haben ja auch Recht. Unser Twee...
# 2     @ahrens_theo fröhlicher gruß aus der schönsten...
# 3     @dushanwegner Amis hätten alles und jeden gewä...
# 4     @spdde kein verläßlicher Verhandlungspartner. ...
# ...                                                 ...
# 8536  @schlabonski tja, es können einen nicht alle L...
# 8537  @RKnillmann @lawyerberlin @AfD Aha, der Islam ...
# 8538  @podilein Mannheim, weltoffen und kunterbunt. ...
# 8539  @stephanweil was ist nun mit kostenlosen Kitas...
# 8540  @Bartzissey Denn Minderheiten sind für Linke j...
#
#                                                  tokens
# 0     liebe corinna gerne moderatorin gewinnen wärst...
# 1     recht tweet bverfg sachleistungen ausschließt ...
# ...

# %%
# ohne Duplikate und vorbearbeitet
docs = tweets_df_new_germ_2018['tokens']

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer


german_stop_words = stopwords.words('german')

german_stop_words.append('lbr')

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                            Name
# 0      -1   3079                   -1_schon_mehr_deutschland_mal
# 1       0   1576                     0_merkel_danke_kinder_immer
# 2       1    424                    1_islam_moslems_israel_juden
# 3       2    363      2_deutschen_deutschland_deutsche_deutscher
# 4       3    212          3_flüchtlinge_asylanten_asyl_migranten
# ..    ...    ...                                             ...
# 84     83     12            83_anwalt_staatsanwalt_seltsames_ruh
# 85     84     12         84_millionen_marode_renten_steuergelder
# 86     85     12  85_soziale_sozialer_gerechtigkeit_sozialsystem
# 87     86     11           86_npd_schafft_abgezogen_federführend
# 88     87     10         87_araber_arabischen_uhr_überflüssigste
#
# [89 rows x 3 columns]

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                        Name
# 0      -1   3079               -1_schon_mehr_deutschland_mal
# 1       0   1576                 0_merkel_danke_kinder_immer
# 2       1    424                1_islam_moslems_israel_juden
# 3       2    363  2_deutschen_deutschland_deutsche_deutscher
# 4       3    212      3_flüchtlinge_asylanten_asyl_migranten
# 5       4    125       4_medien_journalismus_propaganda_news
# 6       5    113                     5_grünen_grün_grüne_rot
# 7       6    101         6_tweet_twitter_antworten_retweeten
# 8       7     99               7_türkei_türken_türke_erdogan
# 9       8     98    8_politiker_politik_politikern_politisch
# 10      9     81           9_geld_kosten_milliarden_bezahlen
# 11     10     73                  10_nazi_nazis_afd_neonazis
# 12     11     70             11_essen_kaffee_fresse_gegessen
# 13     12     67            12_dumm_idioten_dummheit_einfach
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#topic_model.save("tm_germeval2018_processed")

# %%
#topic_model = BERTopic.load("tm_germeval2018_processed")

# %% [markdown]
# # TM GermEval 2018: updated stopwords

# %%
most_frequent_words = pd.Series(' '.join(tweets_df_new_germ_2018['tokens']).lower().split()).value_counts()[:50].index.tolist()
most_frequent_words
# Out:
# ['lbr',
#  'schon',
#  'mehr',
#  'mal',
#  'deutschland',
#  'merkel',
#  'immer',
#  'gibt',
#  'wer',
#  'heute',
#  'geht',
#  'spd',
#  'deutschen',
#  'deutsche',
#  'gut',
#  'land',
#  'menschen',
#  'afd',
#  'müssen',
#  'amp',
#  'wäre',
#  'frauen',
#  'macht',
#  'warum',
#  'einfach',
#  'frau',
#  'wurde',
#  'seit',
#  'leben',
#  'lassen',
#  'gerade',
#  'islam',
#  'eigentlich',
#  'kommt',
#  'besser',
#  'endlich',
#  'tun',
#  'grünen',
#  'macmike',
#  'zeit',
#  'volk',
#  'genau',
#  'wohl',
#  'partei',
#  'erst',
#  'danke',
#  'steht',
#  'dafür',
#  'ganz',
#  'europa']

# %%
not_to_delete = ['europa','partei','grünen','volk','zeit','deutschland','merkel',
                 'spd','deutsche','deutschen','gut','land','menschen','afd',
                 'frauen','macht','frau','leben','islam']

# %%
for ele in most_frequent_words:
    if ele in not_to_delete:
      most_frequent_words.remove(ele)

# %%
most_frequent_words
# Out:
# ['lbr',
#  'schon',
#  'mehr',
#  'mal',
#  'immer',
#  'gibt',
#  'wer',
#  'heute',
#  'geht',
#  'müssen',
#  'amp',
#  'wäre',
#  'warum',
#  'einfach',
#  'wurde',
#  'seit',
#  'lassen',
#  'gerade',
#  'eigentlich',
#  'kommt',
#  'besser',
#  'endlich',
#  'tun',
#  'macmike',
#  'genau',
#  'wohl',
#  'erst',
#  'danke',
#  'steht',
#  'dafür',
#  'ganz']

# %%
to_add = ["tweet", "twitter", "retweeten"]

# %%
most_frequent_words.extend(to_add)

# %%
len(most_frequent_words)
# Out:
# 34

# %%
for word in most_frequent_words:
  german_stop_words.append(word)

# %%
german_stop_words = set(german_stop_words)

# %%
german_stop_words = list(german_stop_words)

# %%
stop_words=german_stop_words

# %%
tweets_df_new_germ_2018 = tokenize_tweets(tweets_df_new_germ_2018)
tweets_df_new_germ_2018
# Out:
# Complete. Number of Tweets that have been cleaned and tokenized : 8541
#                                                   tweet  \
# 0     @corinnamilborn Liebe Corinna, wir würden dich...
# 1     @Martin28a Sie haben ja auch Recht. Unser Twee...
# 2     @ahrens_theo fröhlicher gruß aus der schönsten...
# 3     @dushanwegner Amis hätten alles und jeden gewä...
# 4     @spdde kein verläßlicher Verhandlungspartner. ...
# ...                                                 ...
# 8536  @schlabonski tja, es können einen nicht alle L...
# 8537  @RKnillmann @lawyerberlin @AfD Aha, der Islam ...
# 8538  @podilein Mannheim, weltoffen und kunterbunt. ...
# 8539  @stephanweil was ist nun mit kostenlosen Kitas...
# 8540  @Bartzissey Denn Minderheiten sind für Linke j...
#
#                                                  tokens
# 0     liebe corinna gerne moderatorin gewinnen wärst...
# 1     recht bverfg sachleistungen ausschließt kritis...
# ...

# %%
# ohne Duplikate und vorbearbeitet
docs = tweets_df_new_germ_2018['tokens']

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#      Topic  Count                                           Name
# 0       -1   3362          -1_deutschland_deutschen_spd_deutsche
# 1        0   1037               0_kinder_fröhlicher_gruß_freunde
# 2        1    349             1_islam_moslems_muslime_islamisten
# 3        2    251     2_deutsche_deutschland_deutschen_deutscher
# 4        3    216         3_flüchtlinge_asylanten_asyl_migranten
# ..     ...    ...                                            ...
# 98      97     12               97_araber_arabischen_arabien_uhr
# 99      98     12  98_volksverräter_angreifer_verräterin_kämpfer
# 100     99     12              99_wochenende_sommer_hohe_freitag
# 101    100     11                 100_fußball_köln_sport_abstieg
# 102    101     10   101_grenzen_außengrenzen_angepasst_sicherung
#
# [103 rows x 3 columns]

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                               Name
# 0      -1   3362              -1_deutschland_deutschen_spd_deutsche
# 1       0   1037                   0_kinder_fröhlicher_gruß_freunde
# 2       1    349                 1_islam_moslems_muslime_islamisten
# 3       2    251         2_deutsche_deutschland_deutschen_deutscher
# 4       3    216             3_flüchtlinge_asylanten_asyl_migranten
# 5       4    183                       4_merkel_vasallen_ddr_vasall
# 6       5    111                            5_grünen_grün_grüne_rot
# 7       6    111                      6_türkei_türken_türke_erdogan
# 8       7    102              7_medien_journalismus_propaganda_news
# 9       8     93         8_politiker_politik_politikern_politischen
# 10      9     77                      9_geld_bezahlen_zahlen_kosten
# 11     10     77                  10_nazis_nazi_faschismus_neonazis
# 12     11     76                   11_partei_koalition_parteien_spd
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#topic_model.save("tm_germeval2018_updated_stopwords")

# %%
#topic_model = BERTopic.load("tm_germeval2018_updated_stopwords")

# %% [markdown]
# # TM GermEval 2019: unprocessed

# %%
tweets_df_germ_2019 = df_germeval2019.copy()
tweets_df_germ_2019
# Out:
#                                                   TWEET      OFF        CAT
# 0     @jouwatch Hat die Polizei keine Kanone mehr ? ...  OFFENSE      ABUSE
# 1     @de_sputnik @Saudi Arabien habt ihr mal wieder...  OFFENSE      ABUSE
# 2     Glaube ich nicht , die Bundesregierung so wie ...  OFFENSE      ABUSE
# 3     " Doch schockierend viele Jugendliche wissen k...  OFFENSE  PROFANITY
# 4     Sein Charakter war ihm wichtiger anstatt als b...  OFFENSE  PROFANITY
# ...                                                 ...      ...        ...
# 7021  Es fand aber nie eine Emanzipierungs-Phase der...      NaN        NaN
# 7022  Um es klar zu stellen: Ich will hier kein Whit...      NaN        NaN
# 7023  Und dann habe ich da noch die McArthur-Briefe ...      NaN        NaN
# 7024  Mal sehen wer der Ersatzmann wird. Hier könnte...      NaN        NaN
# 7025  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...      NaN        NaN
#
# [7026 rows x 3 columns]

# %%
docs = tweets_df_germ_2019['TWEET'].copy()

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer


german_stop_words = stopwords.words('german')

# %%
pip install --upgrade tbb
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 5.2 MB/s
# ...

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)

# %%
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")

# %%
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# ...

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                           Name
# 0      -1   2735                             -1_lbr_mal_ja_mehr
# 1       0    400          0_0001f602_0001f621_0001f44d_0001f609
# 2       1    310        1_deutschland_deutschen_deutsche_berlin
# 3       2    285                   2_frauen_frau_männer_mädchen
# 4       3    212                     3_aachen_uhr_frankfurt_amp
# ..    ...    ...                                            ...
# 71     70     12        70_afd_etablierten_bedanken_altparteien
# 72     71     11                      71_hund_ligurrio_per_ibes
# 73     72     11  72_jkasek_gegenüber_matador_zeitverschwendung
# 74     73     11               73_hassanhadjali_glaub_kotzen_ne
# 75     74     11         74_repression_demo_etwa_demonstrierten
#
# [76 rows x 3 columns]

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                               Name
# 0      -1   2735                                 -1_lbr_mal_ja_mehr
# 1       0    400              0_0001f602_0001f621_0001f44d_0001f609
# 2       1    310            1_deutschland_deutschen_deutsche_berlin
# 3       2    285                       2_frauen_frau_männer_mädchen
# 4       3    212                         3_aachen_uhr_frankfurt_amp
# 5       4    204                        4_lbr_titten_ficker_kleinen
# 6       5    159                       5_fcsp_punkte_pauli_gewinnen
# 7       6    150                        6_twitter_tweet_tweets_blog
# 8       7    137                    7_islam_0001f3fb_0001f595_saudi
# 9       8    128                    8_nazis_nazi_nazifresser_hitler
# 10      9     95                         9_merkel_merkels_stasi_cdu
# 11     10     90         10_journalisten_medien_0001f44f_propaganda
# 12     11     84      11_venezuela_maduro_sanktionen_sozialistische
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#from bertopic import BERTopic
#topic_model = BERTopic()
topic_model.save("tm_germeval2019_unprocessed")

# %%
topic_model = BERTopic.load("tm_germeval2019_unprocessed")

# %% [markdown]
# # TM GermEval 2019: processed

# %%
tweets_df_new_germ_2019 = tweets_df_germ_2019[['TWEET']].copy()

tweets_df_new_germ_2019 = tweets_df_new_germ_2019.rename(columns={'TWEET':'tweet'})

# %%
tweets_df_new_germ_2019
# Out:
#                                                   tweet
# 0     @jouwatch Hat die Polizei keine Kanone mehr ? ...
# 1     @de_sputnik @Saudi Arabien habt ihr mal wieder...
# 2     Glaube ich nicht , die Bundesregierung so wie ...
# 3     " Doch schockierend viele Jugendliche wissen k...
# 4     Sein Charakter war ihm wichtiger anstatt als b...
# ...                                                 ...
# 7021  Es fand aber nie eine Emanzipierungs-Phase der...
# 7022  Um es klar zu stellen: Ich will hier kein Whit...
# 7023  Und dann habe ich da noch die McArthur-Briefe ...
# 7024  Mal sehen wer der Ersatzmann wird. Hier könnte...
# 7025  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...
#
# [7026 rows x 1 columns]

# %%
#tweets_df_new = tweets_df_new.drop('TWEET', axis=1)

# %%
tweets_df_new_germ_2019 = tokenize_tweets(tweets_df_new_germ_2019)
tweets_df_new_germ_2019
# Out:
# Complete. Number of Tweets that have been cleaned and tokenized : 7026
#                                                   tweet  \
# 0     @jouwatch Hat die Polizei keine Kanone mehr ? ...
# 1     @de_sputnik @Saudi Arabien habt ihr mal wieder...
# 2     Glaube ich nicht , die Bundesregierung so wie ...
# 3     " Doch schockierend viele Jugendliche wissen k...
# 4     Sein Charakter war ihm wichtiger anstatt als b...
# ...                                                 ...
# 7021  Es fand aber nie eine Emanzipierungs-Phase der...
# 7022  Um es klar zu stellen: Ich will hier kein Whit...
# 7023  Und dann habe ich da noch die McArthur-Briefe ...
# 7024  Mal sehen wer der Ersatzmann wird. Hier könnte...
# 7025  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...
#
#                                                  tokens
# 0     polizei kanone mehr mal munition laufen lassen...
# 1     arabien habt mal orgasmus gebaucht weswegen ha...
# ...

# %%
# ohne Duplikate und vorbearbeitet
docs = tweets_df_new_germ_2019['tokens']

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer


german_stop_words = stopwords.words('german')

german_stop_words.append('lbr')

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                               Name
# 0      -1   2660                            -1_mal_schon_mehr_immer
# 1       0   1477                           0_kinder_danke_uhr_heute
# 2       1    424            1_deutschland_deutsche_deutschen_berlin
# 3       2    368              2_politik_partei_politiker_demokratie
# 4       3    185                   3_tweet_twitter_twittern_stegner
# 5       4    156                       4_nazis_nazi_neonazis_hitler
# 6       5     93            5_medien_journalisten_propaganda_google
# 7       6     89      6_flüchtlinge_migranten_flüchtlingen_refugees
# 8       7     89     7_israel_palästinenser_zionistischen_zionisten
# 9       8     87                            8_hund_wolf_hunde_affen
# 10      9     86                      9_islam_arabien_muslime_saudi
# 11     10     72                        10_text_lesen_gelesen_texte
# 12     11     52               11_rassismus_rassisten_weiße_rassist
# ...

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                               Name
# 0      -1   2660                            -1_mal_schon_mehr_immer
# 1       0   1477                           0_kinder_danke_uhr_heute
# 2       1    424            1_deutschland_deutsche_deutschen_berlin
# 3       2    368              2_politik_partei_politiker_demokratie
# 4       3    185                   3_tweet_twitter_twittern_stegner
# 5       4    156                       4_nazis_nazi_neonazis_hitler
# 6       5     93            5_medien_journalisten_propaganda_google
# 7       6     89      6_flüchtlinge_migranten_flüchtlingen_refugees
# 8       7     89     7_israel_palästinenser_zionistischen_zionisten
# 9       8     87                            8_hund_wolf_hunde_affen
# 10      9     86                      9_islam_arabien_muslime_saudi
# 11     10     72                        10_text_lesen_gelesen_texte
# 12     11     52               11_rassismus_rassisten_weiße_rassist
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#topic_model.save("tm_germeval2019_processed")

# %%
#topic_model = BERTopic.load("tm_germeval2019_processed")

# %% [markdown]
# # TM GermEval 2019: updated stopwords

# %%
most_frequent_words = pd.Series(' '.join(tweets_df_new_germ_2019['tokens']).lower().split()).value_counts()[:50].index.tolist()
most_frequent_words

# %%
not_to_delete = ["deutschland", "menschen", "macht", "afd", "spd", "deutsche", "leben", "land", "merkel", "frau", "deutschen","frauen", "hartz"]

# %%
for word in most_frequent_words:
  if word in not_to_delete:
    most_frequent_words.remove(word)

# %%
most_frequent_words

# %%
add_to_most_frequent = ["besser", "nix", "sagt", "twitter", "twittern", "retweeten", "schönen", "moin", "feiern", "minuten", "stunden", "zeit", "datum", "tipp"]

# %%
most_frequent_words.extend(add_to_most_frequent)

# %%
most_frequent_words

# %%
for word in most_frequent_words:
  german_stop_words.append(word)

# %%
set(german_stop_words)

# %%
list(german_stop_words)

# %%
for word in german_stop_words:
  if word in not_to_delete:
    german_stop_words.remove(word)

# %%
german_stop_words = set(german_stop_words)

# %%
list(german_stop_words)

# %%
stop_words=german_stop_words

# %%
tweets_df_new_germ_2019 = tokenize_tweets(tweets_df_new_germ_2019)
tweets_df_new_germ_2019
# Out:
# Complete. Number of Tweets that have been cleaned and tokenized : 7026
#                                                   tweet  \
# 0     @jouwatch Hat die Polizei keine Kanone mehr ? ...
# 1     @de_sputnik @Saudi Arabien habt ihr mal wieder...
# 2     Glaube ich nicht , die Bundesregierung so wie ...
# 3     " Doch schockierend viele Jugendliche wissen k...
# 4     Sein Charakter war ihm wichtiger anstatt als b...
# ...                                                 ...
# 7021  Es fand aber nie eine Emanzipierungs-Phase der...
# 7022  Um es klar zu stellen: Ich will hier kein Whit...
# 7023  Und dann habe ich da noch die McArthur-Briefe ...
# 7024  Mal sehen wer der Ersatzmann wird. Hier könnte...
# 7025  @JKasek Oder die Bäume. Bin mal in 'nem Wald s...
#
#                                                  tokens
# 0                   polizei kanone munition laufen ruhe
# 1     arabien habt orgasmus gebaucht weswegen habt f...
# ...

# %%
# ohne Duplikate und vorbearbeitet
docs = tweets_df_new_germ_2019['tokens']

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")
topics, probs = topic_model.fit_transform(docs)

# %%
stop_words

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                             Name
# 0       0   3275            0_deutschland_deutsche_menschen_nazis
# 1      -1   2949                       -1_macht_menschen_spd_land
# 2       1    285               1_islam_israel_juden_palästinenser
# 3       2     97  2_flüchtlinge_migranten_flüchtlingen_flüchtling
# 4       3     61                   3_job_arbeit_arbeiten_arbeiter
# 5       4     54                4_rassismus_rassisten_rassist_ffe
# 6       5     51                   5_klimawandel_klima_winter_co²
# 7       6     39                6_türkei_türken_kurden_kurdischen
# 8       7     38               7_fahrer_autobahn_radfahrer_schnee
# 9       8     37                         8_grüne_grünen_groko_spd
# 10      9     25                    9_russland_russen_putin_china
# 11     10     20                    10_account_facebook_login_bäh
# 12     11     19       11_venezuela_brasilien_imperialisten_monat
# ...

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                             Name
# 0       0   3275            0_deutschland_deutsche_menschen_nazis
# 1      -1   2949                       -1_macht_menschen_spd_land
# 2       1    285               1_islam_israel_juden_palästinenser
# 3       2     97  2_flüchtlinge_migranten_flüchtlingen_flüchtling
# 4       3     61                   3_job_arbeit_arbeiten_arbeiter
# 5       4     54                4_rassismus_rassisten_rassist_ffe
# 6       5     51                   5_klimawandel_klima_winter_co²
# 7       6     39                6_türkei_türken_kurden_kurdischen
# 8       7     38               7_fahrer_autobahn_radfahrer_schnee
# 9       8     37                         8_grüne_grünen_groko_spd
# 10      9     25                    9_russland_russen_putin_china
# 11     10     20                    10_account_facebook_login_bäh
# 12     11     19       11_venezuela_brasilien_imperialisten_monat
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#topic_model.save("tm_germeval2019_updated_stopwords")

# %%
#topic_model = BERTopic.load("tm_germeval2019_updated_stopwords")

# %% [markdown]
# # TM HASOC 2019: unprocessed

# %%
tweets_df_hasoc2019 = df_hasoc2019.copy()
tweets_df_hasoc2019
# Out:
#             text_id                                               text task_1  \
# 0        hasoc_de_1  Frank Rennicke – Ich bin stolz https://t.co/Cm...    NOT
# 1        hasoc_de_2  ANSEHEN.....und danach bitte TEILEN...TEILEN.....    NOT
# 2        hasoc_de_3  #Koeln Mohamed erkennt kein deutsches Recht so...    NOT
# 3        hasoc_de_4  #SaudiArabien ist eine brutale islamische Dikt...    NOT
# 4        hasoc_de_5  Bundespolizei #München hat im 1. Quartal 2019 ...    NOT
# ...             ...                                                ...    ...
# 4664  hasoc_de_6115  #Erdogan ruft seine Mops wegen Untauglichkeit ...    HOF
# 4665  hasoc_de_6116  Ich würde der Linken Chefin Kipping die 1.000 ...    HOF
# 4666  hasoc_de_6117  Ausländer sind Top &amp; Trumpf  Schon aufgefa...    HOF
# 4667  hasoc_de_6118  Wie der Regierungsjet die Regierungsflieger wi...    HOF
# 4668  hasoc_de_6120  #guteMütter  sind heutzutage gut ausgebildete ...    NOT
#
#      task_2
# 0      NONE
# ...

# %%
docs = tweets_df_hasoc2019['text']

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer


german_stop_words = stopwords.words('german')

# %%
pip install --upgrade tbb

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)

# %%
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")

# %%
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                              Name
# 0      -1   1720                               -1_https_co_afd_mal
# 1       0    288  0_flüchtlinge_migranten_asylbewerber_deutschland
# 2       1    236                     1_islam_muslime_moslems_akbar
# 3       2    211               2_deutschland_berlin_fußball_bayern
# 4       3    118                     3_https_co_sprüche_enfkxfx2oi
# ..    ...    ...                                               ...
# 65     64     11                       64_banken_zinsen_dwn_online
# 66     65     11                      65_fliegen_kriegt_mica_feine
# 67     66     10     66_impfpflicht_organspende_krankenschein_tote
# 68     67     10    67_afrika_abschiebung_afrikaner_klimaerwärmung
# 69     68     10             68_komiker_capitol_xprg8ii16c_brüller
#
# [70 rows x 3 columns]

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                              Name
# 0      -1   1720                               -1_https_co_afd_mal
# 1       0    288  0_flüchtlinge_migranten_asylbewerber_deutschland
# 2       1    236                     1_islam_muslime_moslems_akbar
# 3       2    211               2_deutschland_berlin_fußball_bayern
# 4       3    118                     3_https_co_sprüche_enfkxfx2oi
# 5       4     76                       4_merkel_angela_merkels_akk
# 6       5     72           5_journalismus_medien_wahrheit_relotius
# 7       6     72                           6_grünen_grüne_grün_öko
# 8       7     71                 7_rebecca_findbecci_endlich_sucht
# 9       8     69                         8_spd_sarrazin_sed_retten
# 10      9     68             9_europawahl2019_europawahl_ep2019_eu
# 11     10     67    10_afd_verfassungsschutz_rechtsradikale_antifa
# 12     11     67                            11_och_https_co_teilen
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#from bertopic import BERTopic
#topic_model = BERTopic()
#topic_model.save("tm_hasoc2019_unprocessed")

# %%
#topic_model = BERTopic.load("tm_hasoc2019_unprocessed")

# %% [markdown]
# # TM HASOC 2019: processed

# %%
tweets_df_new_hasoc2019 = tweets_df_hasoc2019[['text']].copy()

tweets_df_new_hasoc2019
# Out:
#                                                    text
# 0     Frank Rennicke – Ich bin stolz https://t.co/Cm...
# 1     ANSEHEN.....und danach bitte TEILEN...TEILEN.....
# 2     #Koeln Mohamed erkennt kein deutsches Recht so...
# 3     #SaudiArabien ist eine brutale islamische Dikt...
# 4     Bundespolizei #München hat im 1. Quartal 2019 ...
# ...                                                 ...
# 4664  #Erdogan ruft seine Mops wegen Untauglichkeit ...
# 4665  Ich würde der Linken Chefin Kipping die 1.000 ...
# 4666  Ausländer sind Top &amp; Trumpf  Schon aufgefa...
# 4667  Wie der Regierungsjet die Regierungsflieger wi...
# 4668  #guteMütter  sind heutzutage gut ausgebildete ...
#
# [4669 rows x 1 columns]

# %%
tweets_df_new_hasoc2019 = tweets_df_new_hasoc2019.rename(columns={'text':'tweet'})

# %%
#tweets_df_new = tweets_df_new.drop('TWEET', axis=1)

# %%
tweets_df_new_hasoc2019 = tokenize_tweets(tweets_df_new_hasoc2019)
tweets_df_new_hasoc2019
# Out:
# Complete. Number of Tweets that have been cleaned and tokenized : 4669
#                                                   tweet  \
# 0     Frank Rennicke – Ich bin stolz https://t.co/Cm...
# 1     ANSEHEN.....und danach bitte TEILEN...TEILEN.....
# 2     #Koeln Mohamed erkennt kein deutsches Recht so...
# 3     #SaudiArabien ist eine brutale islamische Dikt...
# 4     Bundespolizei #München hat im 1. Quartal 2019 ...
# ...                                                 ...
# 4664  #Erdogan ruft seine Mops wegen Untauglichkeit ...
# 4665  Ich würde der Linken Chefin Kipping die 1.000 ...
# 4666  Ausländer sind Top &amp; Trumpf  Schon aufgefa...
# 4667  Wie der Regierungsjet die Regierungsflieger wi...
# 4668  #guteMütter  sind heutzutage gut ausgebildete ...
#
#                                                  tokens
# 0                                  frank rennicke stolz
# 1             ansehen danach bitte teilen teilen teilen
# ...

# %%
# ohne Duplikate und vorbearbeitet
docs = tweets_df_new_hasoc2019['tokens']

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer


german_stop_words = stopwords.words('german')

german_stop_words.append('lbr')

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                           Name
# 0      -1   1565                    -1_mal_deutschland_amp_mehr
# 1       0    213              0_viele_immer_hass_wahrscheinlich
# 2       1    212              1_demokratie_parteien_partei_wahl
# 3       2    175                  2_islam_muslime_moslems_akbar
# 4       3    165                                       3_the___
# ..    ...    ...                                            ...
# 64     63     11            63_cdu_transistor_mikrophon_emitter
# 65     64     11                   64_rheinland_pfalz_mainz_mdl
# 66     65     11                  65_manu_sinnvolleres_mat_norm
# 67     66     11                66_himmel_bewegte_fahne_märchen
# 68     67     10  67_sexsklaverei_vertrag_vergewaltigen_werbung
#
# [69 rows x 3 columns]

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                            Name
# 0      -1   1565                     -1_mal_deutschland_amp_mehr
# 1       0    213               0_viele_immer_hass_wahrscheinlich
# 2       1    212               1_demokratie_parteien_partei_wahl
# 3       2    175                   2_islam_muslime_moslems_akbar
# 4       3    165                                        3_the___
# 5       4    145              4_wahr_friedlich_drecks_tankstelle
# 6       5    118  5_flüchtlinge_migranten_asylbewerber_migration
# 7       6    111                         6_grünen_grüne_grün_rot
# 8       7    102                   7_kinder_mutter_schule_männer
# 9       8     96                       8_danke_stolz_sch_wünsche
# 10      9     83                   9_deutsch_junge_blabla_thelen
# 11     10     71  10_medien_journalismus_journalisten_propaganda
# 12     11     71             11_christen_kirchen_kirche_religion
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#topic_model.save("tm_hasoc2019_processed")

# %%
#topic_model = BERTopic.load("tm_hasoc2019_processed")

# %% [markdown]
# # TM HASOC 2019: updated stopwords

# %%
most_frequent_words = pd.Series(' '.join(tweets_df_new_hasoc2019['tokens']).lower().split()).value_counts()[:50].index.tolist()
most_frequent_words
# Out:
# ['mal',
#  'mehr',
#  'deutschland',
#  'schon',
#  'immer',
#  'wer',
#  'afd',
#  'amp',
#  'geht',
#  'gibt',
#  'land',
#  'wurde',
#  'heute',
#  'warum',
#  'grünen',
#  'menschen',
#  'spd',
#  'frau',
#  'deutsche',
#  'via',
#  'merkel',
#  'polizei',
#  'gut',
#  'ganz',
#  'kommt',
#  'endlich',
#  'beim',
#  'macht',
#  'leben',
#  'jahre',
#  'wäre',
#  'wohl',
#  'wegen',
#  'deutschen',
#  'müssen',
#  'mann',
#  'bitte',
#  'jahren',
#  'seit',
#  'viele',
#  'kinder',
#  'einfach',
#  'sagen',
#  'danke',
#  'dafür',
#  'cdu',
#  'erst',
#  'frauen',
#  'welt',
#  'nie']

# %%
not_to_delete = ['deutschland', 'afd', 'land', 'grünen', 'menschen', 'spd', 'frau', 'deutsche', 'merkel', 'polizei', 'leben', 'deutschen', 'mann', 'kinder', 'cdu', 'frauen', 'welt']

#most_frequent_words = most_frequent_words.drop(['deutschland'])

# %%
for ele in most_frequent_words:
    if ele in not_to_delete:
      most_frequent_words.remove(ele)

# %%
len(most_frequent_words)
# Out:
# 33

# %%
most_frequent_words
# Out:
# ['mal',
#  'mehr',
#  'schon',
#  'immer',
#  'wer',
#  'amp',
#  'geht',
#  'gibt',
#  'wurde',
#  'heute',
#  'warum',
#  'via',
#  'gut',
#  'ganz',
#  'kommt',
#  'endlich',
#  'beim',
#  'macht',
#  'jahre',
#  'wäre',
#  'wohl',
#  'wegen',
#  'müssen',
#  'bitte',
#  'jahren',
#  'seit',
#  'viele',
#  'einfach',
#  'sagen',
#  'danke',
#  'dafür',
#  'erst',
#  'nie']

# %%
additional_stopwords = ["amp", "wahrscheinlich", "sch", "blabla", "twitter", "tweet", "account", "gelöscht", "the", "bla"]

# %%
for word in additional_stopwords:
  german_stop_words.append(word)

# %%
len(german_stop_words)
# Out:
# 283

# %%
for word in most_frequent_words:
  german_stop_words.append(word)

# %%
german_stop_words = set(german_stop_words)

# %%
german_stop_words = list(german_stop_words)

# %%
german_stop_words.append("klick")

# %%
stop_words=german_stop_words

# %%
tweets_df_new_hasoc2019 = tokenize_tweets(tweets_df_new_hasoc2019)
tweets_df_new_hasoc2019
# Out:
# Complete. Number of Tweets that have been cleaned and tokenized : 4669
#                                                   tweet  \
# 0     Frank Rennicke – Ich bin stolz https://t.co/Cm...
# 1     ANSEHEN.....und danach bitte TEILEN...TEILEN.....
# 2     #Koeln Mohamed erkennt kein deutsches Recht so...
# 3     #SaudiArabien ist eine brutale islamische Dikt...
# 4     Bundespolizei #München hat im 1. Quartal 2019 ...
# ...                                                 ...
# 4664  #Erdogan ruft seine Mops wegen Untauglichkeit ...
# 4665  Ich würde der Linken Chefin Kipping die 1.000 ...
# 4666  Ausländer sind Top &amp; Trumpf  Schon aufgefa...
# 4667  Wie der Regierungsjet die Regierungsflieger wi...
# 4668  #guteMütter  sind heutzutage gut ausgebildete ...
#
#                                                  tokens
# 0                                  frank rennicke stolz
# 1                   ansehen danach teilen teilen teilen
# ...

# %%
# ohne Duplikate und vorbearbeitet
docs = tweets_df_new_hasoc2019['tokens']

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                               Name
# 0      -1   1527                               -1_spd_land_afd_mann
# 1       0   1293                      0_merkel_frau_kinder_menschen
# 2       1    644            1_deutschland_deutsche_deutschen_berlin
# 3       2    202                     2_demokratie_parteien_afd_wahl
# 4       3    162   3_flüchtlinge_migranten_deutschland_asylbewerber
# 5       4    140                      4_islam_muslime_moslems_akbar
# 6       5     75                 5_christen_kirche_kirchen_religion
# 7       6     57      6_klima_klimawandel_erwärmung_wissenschaftler
# 8       7     53                        7_nazis_nazi_antifa_idioten
# 9       8     51                      8_banken_rente_kredite_zahlen
# 10      9     50         9_polizei_polizisten_beamten_abschiebungen
# 11     10     48         10_medien_journalismus_journalisten_presse
# 12     11     41                    11_video_videos_youtube_trailer
# ...

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                              Name
# 0      -1   1527                              -1_spd_land_afd_mann
# 1       0   1293                     0_merkel_frau_kinder_menschen
# 2       1    644           1_deutschland_deutsche_deutschen_berlin
# 3       2    202                    2_demokratie_parteien_afd_wahl
# 4       3    162  3_flüchtlinge_migranten_deutschland_asylbewerber
# 5       4    140                     4_islam_muslime_moslems_akbar
# 6       5     75                5_christen_kirche_kirchen_religion
# 7       6     57     6_klima_klimawandel_erwärmung_wissenschaftler
# 8       7     53                       7_nazis_nazi_antifa_idioten
# 9       8     51                     8_banken_rente_kredite_zahlen
# 10      9     50        9_polizei_polizisten_beamten_abschiebungen
# 11     10     48        10_medien_journalismus_journalisten_presse
# 12     11     41                   11_video_videos_youtube_trailer
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#topic_model.save("tm_hasoc2019_updated_stopwords")

# %%
#topic_model = BERTopic.load("tm_hasoc2019_updated_stopwords")

# %% [markdown]
# # TM HASOC 2020: unprocessed

# %%
tweets_df_hasoc2020 = df_hasoc2020.copy()
tweets_df_hasoc2020
# Out:
#                  tweet_id                                               text  \
# 0     1133388798925189122  Deutsche rothaarige porno reife deutsche fraue...
# 1     1127134592517980161  RT @NDRinfo: Die deutsche Klimaaktivistin Luis...
# 2     1128897106171842560  @ruhrbahn jeden Morgen eine neue „Fahrzeugstör...
# 3     1123576753199484928  @Junge_Freiheit Die Inkas hatten sich schon dä...
# 4     1128743783393312768  RT @technosteron: leute die 'boar' schreiben l...
# ...                   ...                                                ...
# 2894  1124809878546128897  RT @ChanMachtSo: SCHMERZEN!!!! Au!!! Mein Gehi...
# 2895  1132433240000798720  Die Zerstörung der Grünen. https://t.co/SIYDJj...
# 2896  1127366294255357958  RT @PParzival: "Antideutsche" Pseudo-linke Ide...
# 2897  1124362090460975105                         Klug reden und dumm leben.
# 2898  1131487097293103104  Wissen wir schon lange....hat das die Merkel e...
#
#      task1 task2                  ID
# ...

# %%
docs = tweets_df_hasoc2020['text']

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer


german_stop_words = stopwords.words('german')

# %%
pip install --upgrade tbb

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)

# %%
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")

# %%
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#     Topic  Count                                               Name
# 0      -1    973                             -1_rt_einfach_gt_arsch
# 1       0    297                              0_co_https_einfach_rt
# 2       1    186                           1_merkel_frau_merkels_co
# 3       2    179                        2_einfach_scheiß_dumm_arsch
# 4       3    167                             3_nazis_nazi_hitler_rt
# 5       4    157                    4_deutsche_deutschland_co_https
# 6       5    121                         5_arsch_gehirn_geiler_hirn
# 7       6    116                     6_islam_moslems_deutschland_rt
# 8       7    103                     7_porno_gratis_deutsche_frauen
# 9       8    102                             8_grünen_grüne_grün_rt
# 10      9     69                      9_dumm_scheiß_scheiße_einfach
# 11     10     65                      10_politiker_politik_co_https
# 12     11     36      11_frauen_gibt_leistungsfähiger_produktivität
# ...

# %%
topic_df.head(20)
# Out:
#     Topic  Count                                           Name
# 0      -1    973                         -1_rt_einfach_gt_arsch
# 1       0    297                          0_co_https_einfach_rt
# 2       1    186                       1_merkel_frau_merkels_co
# 3       2    179                    2_einfach_scheiß_dumm_arsch
# 4       3    167                         3_nazis_nazi_hitler_rt
# 5       4    157                4_deutsche_deutschland_co_https
# 6       5    121                     5_arsch_gehirn_geiler_hirn
# 7       6    116                 6_islam_moslems_deutschland_rt
# 8       7    103                 7_porno_gratis_deutsche_frauen
# 9       8    102                         8_grünen_grüne_grün_rt
# 10      9     69                  9_dumm_scheiß_scheiße_einfach
# 11     10     65                  10_politiker_politik_co_https
# 12     11     36  11_frauen_gibt_leistungsfähiger_produktivität
# 13     12     31       12_grünen_europawahl2019_grüne_deutschen
# ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#from bertopic import BERTopic
#topic_model = BERTopic()
#topic_model.save("tm_hasoc2020_unprocessed")

# %%
#topic_model = BERTopic.load("tm_hasoc2020_unprocessed")

# %% [markdown]
# # TM HASOC 2020: processed

# %%
tweets_df_new_hasoc2020 = tweets_df_hasoc2020[['text']].copy()

# %%
tweets_df_new_hasoc2020 = tweets_df_new_hasoc2020.rename(columns={'text':'tweet'})

# %%
tweets_df_new_hasoc2020
# Out:
#                                                   tweet
# 0     Deutsche rothaarige porno reife deutsche fraue...
# 1     RT @NDRinfo: Die deutsche Klimaaktivistin Luis...
# 2     @ruhrbahn jeden Morgen eine neue „Fahrzeugstör...
# 3     @Junge_Freiheit Die Inkas hatten sich schon dä...
# 4     RT @technosteron: leute die 'boar' schreiben l...
# ...                                                 ...
# 2894  RT @ChanMachtSo: SCHMERZEN!!!! Au!!! Mein Gehi...
# 2895  Die Zerstörung der Grünen. https://t.co/SIYDJj...
# 2896  RT @PParzival: "Antideutsche" Pseudo-linke Ide...
# 2897                         Klug reden und dumm leben.
# 2898  Wissen wir schon lange....hat das die Merkel e...
#
# [2899 rows x 1 columns]

# %%
#tweets_df_new = tweets_df_new.drop('TWEET', axis=1)

# %%
tweets_df_new_hasoc2020 = tokenize_tweets(tweets_df_new_hasoc2020)
tweets_df_new_hasoc2020
# Out:
# Complete. Number of Tweets that have been cleaned and tokenized : 2899
#                                                   tweet  \
# 0     Deutsche rothaarige porno reife deutsche fraue...
# 1     RT @NDRinfo: Die deutsche Klimaaktivistin Luis...
# 2     @ruhrbahn jeden Morgen eine neue „Fahrzeugstör...
# 3     @Junge_Freiheit Die Inkas hatten sich schon dä...
# 4     RT @technosteron: leute die 'boar' schreiben l...
# ...                                                 ...
# 2894  RT @ChanMachtSo: SCHMERZEN!!!! Au!!! Mein Gehi...
# 2895  Die Zerstörung der Grünen. https://t.co/SIYDJj...
# 2896  RT @PParzival: "Antideutsche" Pseudo-linke Ide...
# 2897                         Klug reden und dumm leben.
# 2898  Wissen wir schon lange....hat das die Merkel e...
#
#                                                  tokens
# 0     deutsche rothaarige porno reife deutsche fraue...
# 1     deutsche klimaaktivistin luisa neubauer wirft ...
# ...

# %%
# ohne Duplikate und vorbearbeitet
docs = tweets_df_new_hasoc2020['tokens']

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer


german_stop_words = stopwords.words('german')

german_stop_words.append('lbr')

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#    Topic  Count                                     Name
# 0      0   1139             0_porno_arsch_einfach_gratis
# 1     -1    952               -1_einfach_schon_arsch_mal
# 2      1    455   1_nazis_deutsche_deutschland_deutschen
# 3      2    163                2_grünen_grüne_grün_linke
# 4      3     75        3_islam_moslems_religion_kopftuch
# 5      4     57      4_politiker_politik_dumm_lobbyisten
# 6      5     27  5_medien_journalisten_grünen_staatsfunk
# 7      6     20         6_türkei_türken_erdogan_istanbul
# 8      7     11    7_flüchtlinge_asylanten_bild_wohngege

# %%
topic_df.head(20)
# Out:
#    Topic  Count                                     Name
# 0      0   1139             0_porno_arsch_einfach_gratis
# 1     -1    952               -1_einfach_schon_arsch_mal
# 2      1    455   1_nazis_deutsche_deutschland_deutschen
# 3      2    163                2_grünen_grüne_grün_linke
# 4      3     75        3_islam_moslems_religion_kopftuch
# 5      4     57      4_politiker_politik_dumm_lobbyisten
# 6      5     27  5_medien_journalisten_grünen_staatsfunk
# 7      6     20         6_türkei_türken_erdogan_istanbul
# 8      7     11    7_flüchtlinge_asylanten_bild_wohngege

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#topic_model.save("tm_hasoc2020_processed")

# %%
#topic_model = BERTopic.load("tm_hasoc2020_processed")

# %% [markdown]
# # TM HASOC 2020: updated stopwords

# %%
most_frequent_words = pd.Series(' '.join(tweets_df_new_hasoc2020['tokens']).lower().split()).value_counts()[:50].index.tolist()
most_frequent_words
# Out:
# ['einfach',
#  'deutsche',
#  'arsch',
#  'schon',
#  'mal',
#  'merkel',
#  'scheiß',
#  'grünen',
#  'dumm',
#  'halt',
#  'nazis',
#  'frauen',
#  'porno',
#  'linken',
#  'mehr',
#  'immer',
#  'echt',
#  'gratis',
#  'gibt',
#  'zurück',
#  'islam',
#  'frau',
#  'deutschland',
#  'hurensohn',
#  'grüne',
#  'hört',
#  'politiker',
#  'warum',
#  'welt',
#  'linke',
#  'pack',
#  'scheiße',
#  'erst',
#  'kopf',
#  'eigentlich',
#  'idioten',
#  'fresse',
#  'dumme',
#  'stimmt',
#  'kinder',
#  'leute',
#  'macht',
#  'wäre',
#  'hurensoh',
#  'europa',
#  'lassen',
#  'deutschen',
#  'scheisse',
#  'heute',
#  'besser']

# %%
not_to_del = ['deutschen','scheisse', 'europa', 'hurensoh', 'macht', 'kinder', 'leute', 'fresse', 'idioten', 'kopf', 'scheiße', 'pack', 'linke', 'welt', 'politiker', 'hurensohn', 'deutschland', 'frau', 'islam','linken', 'porno', 'frauen', 'nazis', 'dumm', 'grünen', 'scheiß', 'merkel', 'deutsche', 'arsch']

# %%
not_to_delete = ['frauen','nazis','dumm','grünen','merkel',
                 'deutsche','arsch','porno','deutsche']

# %%
not_to_delete.extend(not_to_del)

# %%
for ele in most_frequent_words:
    if ele in not_to_delete:
      most_frequent_words.remove(ele)

# %%
len(most_frequent_words)
# Out:
# 21

# %%
most_frequent_words.remove('dumme')

# %%
#most_frequent_words = most_frequent_words.drop(['frauen','nazis','dumm','grünen',
#                                                'merkel','deutsche','arsch','porno',
#                                                'deutsche'])

# %%
for word in most_frequent_words:
  german_stop_words.append(word)

# %%
german_stop_words = set(german_stop_words)

# %%
german_stop_words = list(german_stop_words)

# %%
to_append = ['amp', 'same', ]

# %%
german_stop_words.extend(to_append)

# %%
stop_words=german_stop_words

# %%
tweets_df_new_hasoc2020 = tokenize_tweets(tweets_df_new_hasoc2020)
tweets_df_new_hasoc2020
# Out:
# Complete. Number of Tweets that have been cleaned and tokenized : 2899
#                                                   tweet  \
# 0     Deutsche rothaarige porno reife deutsche fraue...
# 1     RT @NDRinfo: Die deutsche Klimaaktivistin Luis...
# 2     @ruhrbahn jeden Morgen eine neue „Fahrzeugstör...
# 3     @Junge_Freiheit Die Inkas hatten sich schon dä...
# 4     RT @technosteron: leute die 'boar' schreiben l...
# ...                                                 ...
# 2894  RT @ChanMachtSo: SCHMERZEN!!!! Au!!! Mein Gehi...
# 2895  Die Zerstörung der Grünen. https://t.co/SIYDJj...
# 2896  RT @PParzival: "Antideutsche" Pseudo-linke Ide...
# 2897                         Klug reden und dumm leben.
# 2898  Wissen wir schon lange....hat das die Merkel e...
#
#                                                  tokens
# 0     deutsche rothaarige porno reife deutsche fraue...
# 1     deutsche klimaaktivistin luisa neubauer wirft ...
# ...

# %%
# ohne Duplikate und vorbearbeitet
docs = tweets_df_new_hasoc2020['tokens']

# %%
vectorizer_model = CountVectorizer(stop_words=german_stop_words)
topic_model = BERTopic(language="german", vectorizer_model=vectorizer_model, calculate_probabilities=False, nr_topics="auto")
topics, probs = topic_model.fit_transform(docs)

# %%
topic_df = topic_model.get_topic_info()
topic_df
# Out:
#    Topic  Count                                        Name
# 0      0   1310               0_arsch_porno_deutsche_frauen
# 1     -1    841                 -1_arsch_scheiß_dumm_merkel
# 2      1    454      1_nazis_deutsche_deutschland_deutschen
# 3      2    123                    2_grünen_grün_rot_jungen
# 4      3     76           3_islam_moslems_religion_kopftuch
# 5      4     28     4_medien_journalisten_staatsfunk_völlig
# 6      5     19            5_türkei_türken_erdogan_istanbul
# 7      6     19  6_flüchtlinge_asylanten_migranten_deutsche
# 8      7     17               7_retweet_tweet_hashtag_magst
# 9      8     12                      8_bus_auto_airbus_tank

# %%
topic_df.head(20)
# Out:
#    Topic  Count                                        Name
# 0      0   1310               0_arsch_porno_deutsche_frauen
# 1     -1    841                 -1_arsch_scheiß_dumm_merkel
# 2      1    454      1_nazis_deutsche_deutschland_deutschen
# 3      2    123                    2_grünen_grün_rot_jungen
# 4      3     76           3_islam_moslems_religion_kopftuch
# 5      4     28     4_medien_journalisten_staatsfunk_völlig
# 6      5     19            5_türkei_türken_erdogan_istanbul
# 7      6     19  6_flüchtlinge_asylanten_migranten_deutsche
# 8      7     17               7_retweet_tweet_hashtag_magst
# 9      8     12                      8_bus_auto_airbus_tank

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#topic_model.save("tm_hasoc2020_updated_stopwords")

# %%
#topic_model = BERTopic.load("tm_hasoc2020_updated_stopwords")
